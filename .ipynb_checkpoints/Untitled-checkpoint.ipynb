# %%
import numpy as np
import pandas as pd

# %%
spreadsheet = pd.read_csv('/Users/danny/Downloads/UNdata_Export_20230714_054021753.csv')

# %%
spreadsheet[(spreadsheet.get('Country or Area') == 'Albania') & (spreadsheet.get('Age') == '15 +')]
# Out:
#     Country or Area  Year   Area     Sex   Age  \
# 9           Albania  2011  Total  Female  15 +
# 10          Albania  2011  Total  Female  15 +
# 11          Albania  2011  Total  Female  15 +
# 12          Albania  2011  Total  Female  15 +
# 13          Albania  2011  Total  Female  15 +
# 14          Albania  2011  Total  Female  15 +
# 15          Albania  2011  Total  Female  15 +
# 16          Albania  2011  Total  Female  15 +
# 17          Albania  2011  Total  Female  15 +
# 153         Albania  2011  Urban  Female  15 +
# 154         Albania  2011  Urban  Female  15 +
# 155         Albania  2011  Urban  Female  15 +
# 156         Albania  2011  Urban  Female  15 +
# 157         Albania  2011  Urban  Female  15 +
# 158         Albania  2011  Urban  Female  15 +
# 159         Albania  2011  Urban  Female  15 +
# 160         Albania  2011  Urban  Female  15 +
# 161         Albania  2011  Urban  Female  15 +
# 297         Albania  2011  Rural  Female  15 +
# ...

# %%
spreadsheet = spreadsheet.groupby('Country or Area').count()
spreadsheet
# Out:
#                                     Year  Area   Sex   Age  \
# Country or Area
# 1                                      1     0     0     0
# 10                                     1     0     0     0
# 11                                     1     0     0     0
# 12                                     1     0     0     0
# 13                                     1     0     0     0
# ...                                  ...   ...   ...   ...
# Uruguay                             1506  1506  1506  1506
# Venezuela (Bolivarian Republic of)  1044  1044  1044  1044
# Viet Nam                             600   600   600   600
# Zambia                                16    16    16    16
# footnoteSeqID                          1     0     0     0
#
#                                     Number of children living  Record Type  \
# Country or Area
# 1                                                           0            0
# ...
